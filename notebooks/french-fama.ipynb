# %%
# %cd ..
# %load_ext autoreload
# %autoreload 2

import pandas as pd
# Out:
# C:\Users\dimitri\workspaces
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Simple French Fama Portfolio Analysis

# %%
from fintools.industry_data import *

brka_d = load_prices('brka_d_ret.csv')
brka_d.head()
# Out:
#                 BRKA
# Date
# 1990-01-02 -0.005764
# 1990-01-03  0.000000
# 1990-01-04  0.005797
# 1990-01-05 -0.005764
# 1990-01-08  0.000000

# %%
from fintools.calculator import *

brka_m = resample_returns(brka_d)
brka_m.head()
# Out:
#              BRKA
# Date
# 1990-01 -0.140634
# 1990-02 -0.030852
# 1990-03 -0.069204
# 1990-04 -0.003717
# 1990-05  0.067164

# %%
from fintools.factor_data import *

fff = load_fff_returns_monthly('F-F_Research_Data_Factors_m.csv')
fff.head()
# Out:
#          Mkt-RF     SMB     HML      RF
# 1926-07  0.0296 -0.0230 -0.0287  0.0022
# 1926-08  0.0264 -0.0140  0.0419  0.0025
# 1926-09  0.0036 -0.0132  0.0001  0.0023
# 1926-10 -0.0324  0.0004  0.0051  0.0032
# 1926-11  0.0253 -0.0020 -0.0035  0.0031

# %%
from fintools.factors import *

lm = french_fama_regression(brka_m, '1990','2012-05', fff_return=fff)
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   BRKA   R-squared:                       0.154
# Model:                            OLS   Adj. R-squared:                  0.150
# Method:                 Least Squares   F-statistic:                     48.45
# Date:                Sat, 29 Jan 2022   Prob (F-statistic):           2.62e-11
# Time:                        08:57:22   Log-Likelihood:                 388.47
# No. Observations:                 269   AIC:                            -772.9
# Df Residuals:                     267   BIC:                            -765.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF         0.5402      0.078      6.961      0.000       0.387       0.693
# ...

# %%
lm = french_fama_regression(brka_m, '1990','2012-05', 
                            fff_return = fff,
                            regression_type = RegressionType.THREE_FACTOR)
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   BRKA   R-squared:                       0.290
# Model:                            OLS   Adj. R-squared:                  0.282
# Method:                 Least Squares   F-statistic:                     36.06
# Date:                Sat, 29 Jan 2022   Prob (F-statistic):           1.41e-19
# Time:                        08:58:10   Log-Likelihood:                 412.09
# No. Observations:                 269   AIC:                            -816.2
# Df Residuals:                     265   BIC:                            -801.8
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF         0.6761      0.074      9.155      0.000       0.531       0.821
# ...
